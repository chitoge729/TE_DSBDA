# %%
import numpy as np
import pandas as pd

# %%
dataset = {
    'name':['ABC','DEF','GHI','JKL','MNO'],
    'rollno':[1,2,3,4,5],
    'math':[50,60,70,80,90]
}

# %%
df = pd.DataFrame(dataset)

# %%
df
# Out:
#   name  rollno  math
# 0  ABC       1    50
# 1  DEF       2    60
# 2  GHI       3    70
# 3  JKL       4    80
# 4  MNO       5    90

# %%
df.isnull()
# Out:
#     name  rollno   math
# 0  False   False  False
# 1  False   False  False
# 2  False   False  False
# 3  False   False  False
# 4  False   False  False

# %%
df.shape
# Out:
# (5, 3)

# %%
df.describe()
# Out:
#          rollno       math
# count  5.000000   5.000000
# mean   3.000000  70.000000
# std    1.581139  15.811388
# min    1.000000  50.000000
# 25%    2.000000  60.000000
# 50%    3.000000  70.000000
# 75%    4.000000  80.000000
# max    5.000000  90.000000

# %%
df.info
# Out:
# <bound method DataFrame.info of   name  rollno  math
# 0  ABC       1    50
# 1  DEF       2    60
# 2  GHI       3    70
# 3  JKL       4    80
# 4  MNO       5    90>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    5 non-null      object
#  1   rollno  5 non-null      int64
#  2   math    5 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 248.0+ bytes

# %%
df.notnull()
# Out:
#    name  rollno  math
# 0  True    True  True
# 1  True    True  True
# 2  True    True  True
# 3  True    True  True
# 4  True    True  True

# %%
df[(df['math']>80)]
# Out:
#   name  rollno  math
# 4  MNO       5    90

# %%
df.fillna(10)
# Out:
#   name  rollno  math
# 0  ABC       1    50
# 1  DEF       2    60
# 2  GHI       3    70
# 3  JKL       4    80
# 4  MNO       5    90

# %%
df.dropna()
# Out:
#   name  rollno  math
# 0  ABC       1    50
# 1  DEF       2    60
# 2  GHI       3    70
# 3  JKL       4    80
# 4  MNO       5    90

# %%
df.replace(to_replace=50, value=100)
# Out:
#   name  rollno  math
# 0  ABC       1   100
# 1  DEF       2    60
# 2  GHI       3    70
# 3  JKL       4    80
# 4  MNO       5    90

# %%
df.interpolate(method='linear', limit_direction='backward')
# Out:
#   name  rollno  math
# 0  ABC       1    50
# 1  DEF       2    60
# 2  GHI       3    70
# 3  JKL       4    80
# 4  MNO       5    90

# %%
df[(df['rollno']>2) | (df['math']>60)]
# Out:
#   name  rollno  math
# 2  GHI       3    70
# 3  JKL       4    80
# 4  MNO       5    90

# %%
df[(df['rollno']>2) & (df['math']>60)]
# Out:
#   name  rollno  math
# 2  GHI       3    70
# 3  JKL       4    80
# 4  MNO       5    90

# %%
test = np.where(df['math']>=70)
df.drop(test[0],inplace=False)
# Out:
#   name  rollno  math
# 0  ABC       1    50
# 1  DEF       2    60
